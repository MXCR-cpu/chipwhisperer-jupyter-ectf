# %% [markdown]
# # Part 4, Topic 2: CPA on Firmware Implementation of AES (SIMULATED)

# %% [markdown]
# ---
# **THIS IS NOT THE COMPLETE TUTORIAL - see file with `(MAIN)` in the name.**
#
# ---

# %% [markdown]
# Instead of performing a capture - just copy this data into the referenced code block. It is a copy of the previously recorded data.

# %%
from cwtraces import sca101_lab_data
import chipwhisperer as cw

data = sca101_lab_data["lab4_1"]()
trace_array =  data["trace_array"]
textin_array = data["textin_array"]
key = data["key"]

# %%
trace_array
# Out:
# array([[-0.10400391, -0.28881836, -0.18212891, ...,  0.07202148,
#          0.09790039,  0.12988281],
#        [-0.10229492, -0.27905273, -0.17504883, ...,  0.08032227,
#          0.1003418 ,  0.13134766],
#        [-0.10424805, -0.28759766, -0.1809082 , ...,  0.0793457 ,
#          0.10375977,  0.1315918 ],
#        ...,
#        [-0.10400391, -0.28491211, -0.17944336, ...,  0.07885742,
#          0.1015625 ,  0.13500977],
#        [-0.09838867, -0.27514648, -0.17285156, ...,  0.07910156,
#          0.10058594,  0.13134766],
#        [-0.10351562, -0.29077148, -0.18823242, ...,  0.0793457 ,
#          0.10205078,  0.13134766]])

# %%
textin_array
# Out:
# array([[155, 248, 248, ...,  73, 254, 160],
#        [232, 164, 225, ..., 232,  77,  67],
#        [ 62, 250, 230, ..., 130,  33,  29],
#        ...,
#        [  8, 108, 176, ...,  63, 199, 121],
#        [130,  91, 134, ..., 177, 192, 138],
#        [ 70, 112,  73, ...,  67,  82,  75]], dtype=uint8)
