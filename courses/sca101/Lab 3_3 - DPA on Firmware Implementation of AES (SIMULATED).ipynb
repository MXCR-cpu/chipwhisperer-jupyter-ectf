# %% [markdown]
# # Part 3, Topic 3: DPA on Firmware Implementation of AES (SIMULATED)

# %% [markdown]
# ---
# **THIS IS NOT THE COMPLETE TUTORIAL - see file with `(MAIN)` in the name.**
#
# ---

# %% [markdown]
# Instead of performing a capture - just copy this data into the referenced code block. It is a copy of the previously recorded data.

# %%
from cwtraces import sca101_lab_data
import chipwhisperer as cw

data = sca101_lab_data["lab3_3"]()
trace_array =  data["trace_array"]
textin_array = data["textin_array"]
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 from cwtraces import sca101_lab_data
#       2 import chipwhisperer as cw
#       4 data = sca101_lab_data["lab3_3"]()
#
# ModuleNotFoundError: No module named 'cwtraces'
