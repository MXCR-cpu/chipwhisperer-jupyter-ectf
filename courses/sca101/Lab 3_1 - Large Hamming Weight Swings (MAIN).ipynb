# %% [markdown]
# # Part 3, Topic 1: Large Hamming Weight Swings (MAIN)

# %% [markdown]
# ---
# NOTE: This lab references some (commercial) training material on [ChipWhisperer.io](https://www.ChipWhisperer.io). You can freely execute and use the lab per the open-source license (including using it in your own courses if you distribute similarly), but you must maintain notice about this source location. Consider joining our training course to enjoy the full experience.
#
# ---

# %% [markdown]
# **SUMMARY:** *In the previous part of the course, you saw that a microcontroller's power consumption changes based on what it's doing. In the case of a simple password check, this allowed us to see how many characters of the password we had correct, eventually resulting in the password being broken.*
#
# *That attack was based on different code execution paths showing up differently in power traces. In this next set of labs, we'll posit that, not only does different instructions affect power consumption, the data being manipulated in the microcontroller also affects power consumption.*
#
#
# **LEARNING OUTCOMES:**
#
# * Using a power measurement to 'validate' a possible device model.
# * Detecting the value of a single bit using power measurement.
# * Breaking AES using the classic DPA attack.

# %% [markdown]
# ## Prerequisites
#
# Hold up! Before you continue, check you've done the following tutorials:
#
# * ☑ Jupyter Notebook Intro (you should be OK with plotting & running blocks).
# * ☑ SCA101 Intro (you should have an idea of how to get hardware-specific versions running).
# * ☑ SCA101 Part 2 (you should understand how power consumption changes based on what code is being run)

# %% [markdown]
# ## Power Trace Gathering
#
# At this point you've got to insert code to perform the power trace capture. There are two options here:
# * Capture from physical device.
# * Read from a file.
#
# You get to choose your adventure - see the two notebooks with the same name of this, but called `(SIMULATED)` or `(HARDWARE)` to continue. Inside those notebooks you should get some code to copy into the following section, which will define the capture function.
#
# Be sure you get the `"✔️ OK to continue!"` print once you run the next cell, otherwise things will fail later on!

# %%
# %run '../utils/save_data.ipynb'
# %run '../utils/plot_traces.ipynb'
# %run '../utils/errors.ipynb'
# Out:
# /Users/xcrbox/Desktop/2026-eCTF/chipwhisperer/jupyter/.venv/lib/python3.10/site-packages/chipwhisperer/capture/trace/TraceWhisperer.py:31: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   import pkg_resources # type: ignore

# %% [markdown]
# ### With Device

# %%
SCOPETYPE = 'OPENADC'
PLATFORM = 'CW312_SAM4S'
CRYPTO_TARGET = 'TINYAES128C'
SS_VER = 'SS_VER_2_1'

# %%
# %run "../../Setup_Scripts/Setup_Generic.ipynb"
# Out:
# INFO: Found ChipWhisperer😍
# scope.gain.gain                          changed from 0                         to 22
# scope.gain.db                            changed from 15.0                      to 25.091743119266056
# scope.adc.samples                        changed from 131124                    to 5000
# scope.clock.clkgen_freq                  changed from 0                         to 7363636.363636363
# scope.clock.adc_freq                     changed from 0                         to 29454545.454545453
# scope.io.tio1                            changed from serial_tx                 to serial_rx
# scope.io.tio2                            changed from serial_rx                 to serial_tx
# scope.io.hs2                             changed from None                      to clkgen
# scope.glitch.phase_shift_steps           changed from 0                         to 4592
# scope.trace.capture.trigger_source       changed from trace trigger, rule #0    to firmware trigger

# %%
# %%bash -s "$PLATFORM" "$CRYPTO_TARGET" "$SS_VER"
# cd ../../../firmware/mcu/simpleserial-aes
# make PLATFORM=$1 CRYPTO_TARGET=$2 SS_VER=$3 -j
# Out:
# Building for platform CW312_SAM4S with CRYPTO_TARGET=TINYAES128C
# SS_VER set to SS_VER_2_1
# SS_VER set to SS_VER_2_1
# Blank crypto options, building for AES128
# arm-none-eabi-gcc (Arm GNU Toolchain 14.3.Rel1 (Build arm-14.174)) 14.3.1 20250623
# Copyright (C) 2024 Free Software Foundation, Inc.
# This is free software; see the source for copying conditions.  There is NO
# warranty; not even for MERCHANTABILITY or FITNESS FOR A PARTICULAR PURPOSE.
#
# mkdir -p objdir-CW312_SAM4S
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# Compiling:
# .
# Compiling:
# Compiling:
# Welcome to another exciting ChipWhisperer target build!!
# Compiling:
# Compiling:
# Compiling:
# Compiling:
# Compiling:
# Compiling:
# Compiling:
# Compiling:
# Compiling:
#     .././simpleserial/simpleserial.c ...    simpleserial-aes.c ...    .././hal//sam4s/uart.c ...    .././hal//sam4s/pio.c ...    .././hal/hal.c ...    .././hal//sam4s/sysclk.c ...    .././crypto/tiny-AES128-C/aes.c ...    .././hal//sam4s/sam4s_hal.c ...    .././hal//sam4s/pmc.c ...    .././crypto/aes-independant.c ...    .././hal//sam4s/system_sam4s.c ...    .././hal//sam4s/startup_sam4s.c ...Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# Done!
# .
# LINKING:
#     simpleserial-aes-CW312_SAM4S.elf ...Memory region         Used Size  Region Size  %age Used
#              rom:        3720 B       128 KB      2.84%
#              ram:        4984 B        64 KB      7.60%
# Done!
# .
# .
# .
# .
# .
# Creating load file for Flash: simpleserial-aes-CW312_SAM4S.bin
# Creating Extended Listing: simpleserial-aes-CW312_SAM4S.lss
# Creating load file for Flash: simpleserial-aes-CW312_SAM4S.hex
# Creating Symbol Table: simpleserial-aes-CW312_SAM4S.sym
# arm-none-eabi-objdump -h -S -z simpleserial-aes-CW312_SAM4S.elf > simpleserial-aes-CW312_SAM4S.lss
# Creating load file for EEPROM: simpleserial-aes-CW312_SAM4S.eep
# arm-none-eabi-nm -n simpleserial-aes-CW312_SAM4S.elf > simpleserial-aes-CW312_SAM4S.sym
# arm-none-eabi-objcopy -O ihex -R .eeprom -R .fuse -R .lock -R .signature simpleserial-aes-CW312_SAM4S.elf simpleserial-aes-CW312_SAM4S.hex
# arm-none-eabi-objcopy -j .eeprom --set-section-flags=.eeprom="alloc,load" \
# --change-section-lma .eeprom=0 --no-change-warnings -O ihex simpleserial-aes-CW312_SAM4S.elf simpleserial-aes-CW312_SAM4S.eep || exit 0
# arm-none-eabi-objcopy -O binary -R .eeprom -R .fuse -R .lock -R .signature simpleserial-aes-CW312_SAM4S.elf simpleserial-aes-CW312_SAM4S.bin
# Size after:
#    text	   data	    bss	    dec	    hex	filename
#    3720	    272	   4712	   8704	   2200	simpleserial-aes-CW312_SAM4S.elf
# +--------------------------------------------------------
# + Default target does full rebuild each time.
# + Specify buildtarget == allquick == to avoid full rebuild
# +--------------------------------------------------------
# +--------------------------------------------------------
# + Built for platform Microchip SAM4S with:
# + CRYPTO_TARGET = TINYAES128C
# + CRYPTO_OPTIONS = AES128C
# +--------------------------------------------------------

# %%
cw.program_target(scope, prog, "../../../firmware/mcu/simpleserial-aes/simpleserial-aes-{}.hex".format(PLATFORM))

# %%
from tqdm.notebook import trange
import numpy as np
import time

scope.gain.gain = 15

def generate_traces(N, bit_position):
    ktp = cw.ktp.Basic()
    trace_array = []

    key, text = ktp.next()
    target.set_key(key)
    
    for i in trange(N, desc='Capturing traces'):
        scope.arm()
        for i in range(bit_position):
            if text[i] & 0x01:
                text[i] = 0xFF
            else:
                text[i] = 0x00
        target.simpleserial_write('p', text)    
        ret = scope.capture()

        if ret:
            print("Target timed out!")
            continue

        response = target.simpleserial_read('r', 16)
        trace = scope.get_last_trace()
        trace_array.append(Trace(trace, text, response, key))
        key, text = ktp.next()
        
    return trace_array

# %%
trace_array = generate_traces(100, 1)
assert len(trace_array) == 100
print("✔️ OK to continue!")
# Out:
# Capturing traces:   0%|          | 0/100 [00:00<?, ?it/s]
# ✔️ OK to continue!

# %%
save_data('lab_3_1_first_traces', trace_array, settings={'num_samples': scope.adc.samples, 'adc_frequency_Hz': scope.clock.adc_freq})
# Out:
# Directory already exists at "/Users/xcrbox/Desktop/2026-eCTF/chipwhisperer/jupyter/courses/sca101/data/lab_3_1_first_traces"

# %% [markdown]
# ### Without Device

# %%
traces, settings = import_data('lab_3_1_first_traces')
# Out:
# Number of Traces: 100

# %% [markdown]
# ## Grouping Traces
#
# As we've seen in the slides, we've made an assumption that setting bits on the data lines consumes a measurable amount of power. Now, we're going test that theory by getting our target to manipulate data with a very high Hamming weight (0xFF) and a very low Hamming weight (0x00). For this purpose, the target is currently running AES, and it encrypted the text we sent it. If we're correct in our assumption, we should see a measurable difference between power traces with a high Hamming weight and a low one.
#
# Currently, these traces are all mixed up. Separate them into two groups: `one_list` and `zero_list`.

# %%
zero_list = list(filter(lambda trace: trace.textin[0] == 0x00, traces))
one_list = list(filter(lambda trace: trace.textin[0] != 0x00, traces))

# %% [markdown]
# Now extend this to append them to two arrays, a `one_list` and a `zero_list`:

# %%
one_list, zero_list
# Out:
# ([Trace(wave=array([-0.20776367, -0.13549805, -0.05859375, ...,  0.06518555,
#           0.0690918 ,  0.09643555]), textin=CWbytearray(b'ff 2c f5 40 44 64 9e 64 cb f9 6f 08 76 2f 75 6d'), textout=CWbytearray(b'9c c9 03 ec b7 c9 c5 91 39 f1 c8 e9 f3 3c c7 fd'), key=CWbytearray(b'2b 7e 15 16 28 ae d2 a6 ab f7 15 88 09 cf 4f 3c')),
#   Trace(wave=array([-0.20166016, -0.14941406, -0.07446289, ...,  0.06689453,
#           0.06274414,  0.1105957 ]), textin=CWbytearray(b'ff 9b 98 b1 9d a5 83 9b d4 3e fb 9b 40 3c 0a 30'), textout=CWbytearray(b'e4 02 6c b6 f6 bc 4a 2c d8 9d bd c8 b1 9b b2 43'), key=CWbytearray(b'2b 7e 15 16 28 ae d2 a6 ab f7 15 88 09 cf 4f 3c')),
#   Trace(wave=array([-0.21728516, -0.14550781, -0.06274414, ...,  0.05932617,
#           0.07495117,  0.09692383]), textin=CWbytearray(b'ff b8 b0 72 1e f3 05 90 08 0f d8 73 6e 2e fd 09'), textout=CWbytearray(b'fb 88 3e 20 94 8d 8e a4 42 da de 9f b4 64 43 10'), key=CWbytearray(b'2b 7e 15 16 28 ae d2 a6 ab f7 15 88 09 cf 4f 3c')),
#   Trace(wave=array([-0.23242188, -0.12988281, -0.05859375, ...,  0.06347656,
#           0.06713867,  0.10546875]), textin=CWbytearray(b'ff 69 ec e6 27 33 44 7a d6 d4 5c 0a c4 02 33 68'), textout=CWbytearray(b'3f 81 db a9 13 c6 b5 6e 0f ea fe 55 ca 90 de d6'), key=CWbytearray(b'2b 7e 15 16 28 ae d2 a6 ab f7 15 88 09 cf 4f 3c')),
#   Trace(wave=array([-0.20263672, -0.12744141, -0.05834961, ...,  0.07080078,
#           0.0715332 ,  0.10791016]), textin=CWbytearray(b'ff a1 95 a8 4a 96 cf 9f 5b a2 f8 33 d0 7b 96 32'), textout=CWbytearray(b'8c d7 cf ec e0 69 c2 05 24 2a 19 b7 3f 29 ac f3'), key=CWbytearray(b'2b 7e 15 16 28 ae d2 a6 ab f7 15 88 09 cf 4f 3c')),
#   Trace(wave=array([-0.21069336, -0.11523438, -0.04858398, ...,  0.07177734,
#           0.07250977,  0.10888672]), textin=CWbytearray(b'ff 27 ff cb 5c bd 3f 31 81 2e 83 98 af 02 f6 cf'), textout=CWbytearray(b'32 53 86 8a 95 77 95 09 b7 59 46 3b aa 6b 08 fa'), key=CWbytearray(b'2b 7e 15 16 28 ae d2 a6 ab f7 15 88 09 cf 4f 3c')),
#   Trace(wave=array([-0.20825195, -0.140625  , -0.06494141, ...,  0.03100586,
#           0.07397461,  0.10864258]), textin=CWbytearray(b'ff d8 cc 88 3c 41 92 48 40 9f 8e f0 f9 ef 87 a8'), textout=CWbytearray(b'7b 1c cf 04 15 56 45 08 07 76 6e cd 19 ca 35 c6'), key=CWbytearray(b'2b 7e 15 16 28 ae d2 a6 ab f7 15 88 09 cf 4f 3c')),
#   Trace(wave=array([-0.2109375 , -0.13452148, -0.03710938, ...,  0.06982422,
#           0.07592773,  0.11206055]), textin=CWbytearray(b'ff 71 27 c7 24 d2 bd 34 77 ce 2c 1e 01 3a 58 10'), textout=CWbytearray(b'db 70 11 09 82 17 fa e8 30 3c 94 d7 05 b0 98 20'), key=CWbytearray(b'2b 7e 15 16 28 ae d2 a6 ab f7 15 88 09 cf 4f 3c')),
#   Trace(wave=array([-0.21875   , -0.13842773, -0.06494141, ...,  0.06420898,
#           0.08081055,  0.10961914]), textin=CWbytearray(b'ff a1 38 3f 22 4b 79 8e 82 14 2f be 5d 53 ab e1'), textout=CWbytearray(b'96 8f 5f e7 c5 48 8d 01 3e 0d ee 78 5d af 4e 06'), key=CWbytearray(b'2b 7e 15 16 28 ae d2 a6 ab f7 15 88 09 cf 4f 3c')),
#   Trace(wave=array([-0.19458008, -0.11962891, -0.06933594, ...,  0.05541992,
#           0.06494141,  0.10375977]), textin=CWbytearray(b'ff ee d4 db bd 65 ad 67 b6 7d 27 8a 6e 42 e9 ef'), textout=CWbytearray(b'74 1c bb a6 99 a6 25 75 90 0f 91 b4 d0 e0 18 f9'), key=CWbytearray(b'2b 7e 15 16 28 ae d2 a6 ab f7 15 88 09 cf 4f 3c')),
#   Trace(wave=array([-0.22216797, -0.14526367, -0.06469727, ...,  0.06787109,
#           0.06958008,  0.10839844]), textin=CWbytearray(b'ff d4 07 15 9c e6 70 11 02 80 4f e5 a5 2f e3 7b'), textout=CWbytearray(b'14 97 01 c5 40 ea 72 6a 67 0b 9c f9 31 0e fb 25'), key=CWbytearray(b'2b 7e 15 16 28 ae d2 a6 ab f7 15 88 09 cf 4f 3c')),
#   Trace(wave=array([-0.21777344, -0.1394043 , -0.09692383, ...,  0.05151367,
#           0.07739258,  0.10253906]), textin=CWbytearray(b'ff f0 af da a3 5f 20 23 37 2b 2a bc c6 94 8a aa'), textout=CWbytearray(b'41 bb 7b 1a b3 02 37 e9 2e 43 18 f2 e9 09 0d fc'), key=CWbytearray(b'2b 7e 15 16 28 ae d2 a6 ab f7 15 88 09 cf 4f 3c')),
#   Trace(wave=array([-0.22119141, -0.13500977, -0.08300781, ...,  0.06152344,
#           0.07324219,  0.10522461]), textin=CWbytearray(b'ff 87 65 4a cc 55 6d 93 25 0a 33 37 51 e8 60 ec'), textout=CWbytearray(b'2c 91 1d d5 ec d4 17 d5 2d 35 8b e8 16 a7 1d 53'), key=CWbytearray(b'2b 7e 15 16 28 ae d2 a6 ab f7 15 88 09 cf 4f 3c')),
#   Trace(wave=array([-0.20849609, -0.14990234, -0.06323242, ...,  0.05419922,
#           0.07104492,  0.10375977]), textin=CWbytearray(b'ff 07 b5 54 bc 2f 38 c9 cb eb 2c 12 83 11 7f 84'), textout=CWbytearray(b'e8 a2 10 bc d0 3c 64 ea c9 75 35 3b 33 fd 97 6a'), key=CWbytearray(b'2b 7e 15 16 28 ae d2 a6 ab f7 15 88 09 cf 4f 3c')),
#   Trace(wave=array([-0.203125  , -0.12744141, -0.05444336, ...,  0.06103516,
#           0.07446289,  0.10473633]), textin=CWbytearray(b'ff b6 f8 41 e3 ea ca 92 36 77 ca c2 41 34 81 d6'), textout=CWbytearray(b'96 75 17 2a 59 85 cc cb 52 5e 1c e5 33 d9 2d 79'), key=CWbytearray(b'2b 7e 15 16 28 ae d2 a6 ab f7 15 88 09 cf 4f 3c')),
#   Trace(wave=array([-0.20385742, -0.13598633, -0.06152344, ...,  0.06616211,
#           0.07128906,  0.10546875]), textin=CWbytearray(b'ff 07 64 45 35 5f 5f b3 02 85 66 51 03 91 5a 8e'), textout=CWbytearray(b'e3 49 48 51 56 ed a2 fe 97 8d d7 cb 32 b4 b8 38'), key=CWbytearray(b'2b 7e 15 16 28 ae d2 a6 ab f7 15 88 09 cf 4f 3c')),
#   Trace(wave=array([-0.21264648, -0.14697266, -0.06201172, ...,  0.06665039,
#           0.07128906,  0.11450195]), textin=CWbytearray(b'ff 95 92 df ed 09 16 6a ce 52 a8 38 b6 12 00 a1'), textout=CWbytearray(b'f3 81 13 24 ca 4f 20 bd 6a 8b 53 bc 20 2a ed 62'), key=CWbytearray(b'2b 7e 15 16 28 ae d2 a6 ab f7 15 88 09 cf 4f 3c')),
#   Trace(wave=array([-0.21655273, -0.14160156, -0.0637207 , ...,  0.06054688,
#           0.07641602,  0.09350586]), textin=CWbytearray(b'ff f1 b9 86 91 97 df 57 09 7a 0e 2f 6a d8 59 6f'), textout=CWbytearray(b'19 94 6c 7a e6 ab e6 4a 66 f7 16 cc d7 2e 08 67'), key=CWbytearray(b'2b 7e 15 16 28 ae d2 a6 ab f7 15 88 09 cf 4f 3c')),
#   Trace(wave=array([-0.21435547, -0.14916992, -0.06689453, ...,  0.06689453,
#           0.07666016,  0.10644531]), textin=CWbytearray(b'ff 13 bb 73 e4 d6 04 ef 09 07 a0 98 f6 2a 0a 61'), textout=CWbytearray(b'e2 d9 47 43 19 ec c9 04 be a7 ad a8 77 58 34 52'), key=CWbytearray(b'2b 7e 15 16 28 ae d2 a6 ab f7 15 88 09 cf 4f 3c')),
#   Trace(wave=array([-0.21704102, -0.14111328, -0.06323242, ...,  0.06738281,
#           0.07836914,  0.10424805]), textin=CWbytearray(b'ff 41 51 36 ef 20 73 e7 0e 35 2e 65 67 c6 96 2e'), textout=CWbytearray(b'f7 ef 26 0c b7 88 b3 0e 37 bf 07 7f db cf 1a 6b'), key=CWbytearray(b'2b 7e 15 16 28 ae d2 a6 ab f7 15 88 09 cf 4f 3c')),
#   Trace(wave=array([-0.21386719, -0.13916016, -0.05322266, ...,  0.05908203,
#           0.07568359,  0.11010742]), textin=CWbytearray(b'ff 25 d0 8a 38 55 4e 03 82 c0 7b 83 59 68 0c 87'), textout=CWbytearray(b'4f 67 ac a5 91 75 b3 3a f0 47 31 51 ff d9 72 1e'), key=CWbytearray(b'2b 7e 15 16 28 ae d2 a6 ab f7 15 88 09 cf 4f 3c')),
#   Trace(wave=array([-0.19873047, -0.13061523, -0.05029297, ...,  0.06689453,
#           0.07104492,  0.09985352]), textin=CWbytearray(b'ff ae c3 ad 53 d1 52 d5 52 83 60 49 d5 1d 48 6d'), textout=CWbytearray(b'94 11 4b ab a8 f2 58 6e 19 cf 52 22 5e d4 a1 54'), key=CWbytearray(b'2b 7e 15 16 28 ae d2 a6 ab f7 15 88 09 cf 4f 3c')),
#   Trace(wave=array([-0.22949219, -0.13867188, -0.06054688, ...,  0.06958008,
#           0.06835938,  0.10864258]), textin=CWbytearray(b'ff dd 38 ca 28 ed 6a 2f e6 2c 6b 3b b1 4f c1 e4'), textout=CWbytearray(b'67 a2 91 d8 07 fc e9 d0 62 5c 04 68 cd f6 78 6c'), key=CWbytearray(b'2b 7e 15 16 28 ae d2 a6 ab f7 15 88 09 cf 4f 3c')),
#   Trace(wave=array([-0.20922852, -0.13500977, -0.05761719, ...,  0.04833984,
#           0.07666016,  0.11157227]), textin=CWbytearray(b'ff a9 7a 3e 45 ca 57 db f0 76 e9 4a e9 bb 76 f5'), textout=CWbytearray(b'0f ad 68 28 8a f8 47 ae b9 96 d9 9c 1f 90 08 a2'), key=CWbytearray(b'2b 7e 15 16 28 ae d2 a6 ab f7 15 88 09 cf 4f 3c')),
#   Trace(wave=array([-0.22045898, -0.13330078, -0.05273438, ...,  0.06005859,
#           0.06518555,  0.10668945]), textin=CWbytearray(b'ff 30 16 ce ca 0a cd f3 65 48 d5 34 ff 5d 65 4f'), textout=CWbytearray(b'73 ff 78 a4 bd 67 46 1d 65 98 ba a6 7d bc fc 03'), key=CWbytearray(b'2b 7e 15 16 28 ae d2 a6 ab f7 15 88 09 cf 4f 3c')),
#   Trace(wave=array([-0.2043457 , -0.13208008, -0.05273438, ...,  0.06298828,
#           0.07446289,  0.10351562]), textin=CWbytearray(b'ff 70 06 08 ef a6 5a e8 fa 78 da 8d 4f 51 82 aa'), textout=CWbytearray(b'ec 9f 83 bb 30 79 7b ee 40 7a 54 b8 7d 00 3c 50'), key=CWbytearray(b'2b 7e 15 16 28 ae d2 a6 ab f7 15 88 09 cf 4f 3c')),
#   Trace(wave=array([-0.21411133, -0.1105957 , -0.05517578, ...,  0.06030273,
#           0.08032227,  0.10375977]), textin=CWbytearray(b'ff 2f dd 40 17 0d 76 10 a0 86 7b e8 df c5 ba 7d'), textout=CWbytearray(b'dd f5 48 77 e3 fa 50 03 93 5b 59 e3 e4 33 a0 39'), key=CWbytearray(b'2b 7e 15 16 28 ae d2 a6 ab f7 15 88 09 cf 4f 3c')),
#   Trace(wave=array([-0.21240234, -0.14575195, -0.06933594, ...,  0.06713867,
#           0.07373047,  0.09887695]), textin=CWbytearray(b'ff a7 83 9e 94 2d c0 27 a8 4c 6a 9d cf b7 7b 30'), textout=CWbytearray(b'aa 25 34 b7 e6 bd 21 04 9a e7 05 9d 10 1d f1 38'), key=CWbytearray(b'2b 7e 15 16 28 ae d2 a6 ab f7 15 88 09 cf 4f 3c')),
#   Trace(wave=array([-0.21508789, -0.13696289, -0.05639648, ...,  0.06787109,
#           0.06542969,  0.10253906]), textin=CWbytearray(b'ff 52 ee 19 5d 04 81 03 d5 be fe 38 38 38 4c b0'), textout=CWbytearray(b'9d d6 92 80 9d f3 db f0 68 99 9a 00 2f 93 b0 51'), key=CWbytearray(b'2b 7e 15 16 28 ae d2 a6 ab f7 15 88 09 cf 4f 3c')),
#   Trace(wave=array([-0.20654297, -0.12841797, -0.06054688, ...,  0.05444336,
#           0.07226562,  0.09545898]), textin=CWbytearray(b'ff 9c 9b d4 3e 42 d3 cd b4 a8 15 0e 7e ad 6e c5'), textout=CWbytearray(b'27 7c c8 d9 ef 7a 7d 0f 4a aa cf 7f 2f 02 22 73'), key=CWbytearray(b'2b 7e 15 16 28 ae d2 a6 ab f7 15 88 09 cf 4f 3c')),
#   Trace(wave=array([-0.21582031, -0.13647461, -0.06713867, ...,  0.05737305,
#           0.0637207 ,  0.10083008]), textin=CWbytearray(b'ff 78 50 37 40 a4 e4 74 3a 7a ae de 19 85 7d 9a'), textout=CWbytearray(b'3c 02 2d 5d 90 44 11 e7 78 fb 7b 34 f5 cf 16 5a'), key=CWbytearray(b'2b 7e 15 16 28 ae d2 a6 ab f7 15 88 09 cf 4f 3c')),
#   Trace(wave=array([-0.2199707 , -0.15380859, -0.06835938, ...,  0.08154297,
#           0.07421875,  0.10327148]), textin=CWbytearray(b'ff 93 3f 6f fa 06 a3 92 04 4b 77 13 3b a0 a3 00'), textout=CWbytearray(b'79 88 db a7 7c 2c 6b 7d 4b 2d 16 dc ce 6b 8e ad'), key=CWbytearray(b'2b 7e 15 16 28 ae d2 a6 ab f7 15 88 09 cf 4f 3c')),
#   Trace(wave=array([-0.2097168 , -0.13818359, -0.06030273, ...,  0.06152344,
#           0.07055664,  0.10913086]), textin=CWbytearray(b'ff 8c 1b 3e 6b ec 97 a9 37 ad 13 30 1c 77 c2 ff'), textout=CWbytearray(b'41 b0 57 e6 37 0f 5b 29 80 c7 03 01 f2 a2 37 a0'), key=CWbytearray(b'2b 7e 15 16 28 ae d2 a6 ab f7 15 88 09 cf 4f 3c')),
#   Trace(wave=array([-0.22070312, -0.14428711, -0.06616211, ...,  0.06420898,
#           0.07006836,  0.10351562]), textin=CWbytearray(b'ff cb 5f c1 c4 c7 71 71 89 33 5e b9 a8 82 5b 49'), textout=CWbytearray(b'4a 14 2a 05 f6 b9 00 4c 17 21 21 37 6f db 7f 7f'), key=CWbytearray(b'2b 7e 15 16 28 ae d2 a6 ab f7 15 88 09 cf 4f 3c')),
#   Trace(wave=array([-0.20581055, -0.13256836, -0.05761719, ...,  0.06420898,
#           0.06396484,  0.10058594]), textin=CWbytearray(b'ff 53 52 79 72 71 7c 3b 1a 5e 4e 79 49 ab 73 22'), textout=CWbytearray(b'93 a6 21 6f 64 b3 2b 77 48 93 2f 65 5b 96 0e 62'), key=CWbytearray(b'2b 7e 15 16 28 ae d2 a6 ab f7 15 88 09 cf 4f 3c')),
#   Trace(wave=array([-0.21655273, -0.14208984, -0.05859375, ...,  0.06152344,
#           0.07055664,  0.11254883]), textin=CWbytearray(b'ff fc d4 74 a6 73 7d b2 a0 b4 88 ae ca 3a 35 aa'), textout=CWbytearray(b'08 4e e0 3e 5b 2d 10 92 3e d3 53 00 7e 58 f7 41'), key=CWbytearray(b'2b 7e 15 16 28 ae d2 a6 ab f7 15 88 09 cf 4f 3c')),
#   Trace(wave=array([-0.19018555, -0.13452148, -0.07275391, ...,  0.07519531,
#           0.0769043 ,  0.10229492]), textin=CWbytearray(b'ff 83 63 71 55 bd 2a d1 89 ac 04 a9 3b 4c 2b 30'), textout=CWbytearray(b'52 4e 24 c4 fb 54 54 9b 7c af 2e 61 bb 53 87 5c'), key=CWbytearray(b'2b 7e 15 16 28 ae d2 a6 ab f7 15 88 09 cf 4f 3c')),
#   Trace(wave=array([-0.21704102, -0.12744141, -0.05395508, ...,  0.06079102,
#           0.07006836,  0.1015625 ]), textin=CWbytearray(b'ff cf 8e a2 f0 bb 11 bc 52 f8 18 69 14 6b de 24'), textout=CWbytearray(b'3d c2 b2 0c 91 96 93 88 7f 84 f8 d7 a6 26 cd ba'), key=CWbytearray(b'2b 7e 15 16 28 ae d2 a6 ab f7 15 88 09 cf 4f 3c')),
#   Trace(wave=array([-0.21923828, -0.14746094, -0.05004883, ...,  0.05908203,
#           0.0690918 ,  0.10058594]), textin=CWbytearray(b'ff 72 1d 57 a8 d7 22 a8 9c 0e 2c e1 c6 05 44 8c'), textout=CWbytearray(b'9e 3c f9 a8 96 04 a2 ca c2 e3 ef 5a f9 3e 28 c7'), key=CWbytearray(b'2b 7e 15 16 28 ae d2 a6 ab f7 15 88 09 cf 4f 3c')),
#   Trace(wave=array([-0.19970703, -0.1394043 , -0.06811523, ...,  0.06665039,
#           0.07202148,  0.11181641]), textin=CWbytearray(b'ff 8d 50 9f 55 7b 36 b5 af 0c 85 89 3f 59 97 74'), textout=CWbytearray(b'13 3b 1c 7b a3 21 cf c3 71 38 b2 e9 4a 94 8b 82'), key=CWbytearray(b'2b 7e 15 16 28 ae d2 a6 ab f7 15 88 09 cf 4f 3c')),
#   Trace(wave=array([-0.21582031, -0.1418457 , -0.06298828, ...,  0.05737305,
#           0.06494141,  0.10400391]), textin=CWbytearray(b'ff 1f 66 f5 39 49 fe ce 54 60 03 e3 60 67 58 aa'), textout=CWbytearray(b'0a 72 15 7c f5 19 9c 96 44 18 2c ed 28 33 46 73'), key=CWbytearray(b'2b 7e 15 16 28 ae d2 a6 ab f7 15 88 09 cf 4f 3c')),
#   Trace(wave=array([-0.2109375 , -0.13427734, -0.05786133, ...,  0.0612793 ,
#           0.06591797,  0.11157227]), textin=CWbytearray(b'ff 6c 35 6d b4 e1 09 9c 8c 78 8c fa 84 1a 82 44'), textout=CWbytearray(b'3b 5e 98 a9 e6 1b 9b ea ce bb fe b3 ff ea 60 e3'), key=CWbytearray(b'2b 7e 15 16 28 ae d2 a6 ab f7 15 88 09 cf 4f 3c')),
#   Trace(wave=array([-0.20556641, -0.15649414, -0.05102539, ...,  0.0637207 ,
#           0.07373047,  0.10546875]), textin=CWbytearray(b'ff db 15 23 68 b4 68 a1 03 22 53 4e 34 5a 49 3b'), textout=CWbytearray(b'e7 74 4d d3 df 2f 28 4c 6f c9 61 69 d2 e1 c1 7c'), key=CWbytearray(b'2b 7e 15 16 28 ae d2 a6 ab f7 15 88 09 cf 4f 3c')),
#   Trace(wave=array([-0.20507812, -0.13525391, -0.06005859, ...,  0.06689453,
#           0.08129883,  0.10522461]), textin=CWbytearray(b'ff 60 aa 4a 68 60 69 62 d3 1b 0a 27 24 f5 2c 4d'), textout=CWbytearray(b'dd 14 3b be 5c 2a c9 cb ba a6 aa 4e dc ff e7 74'), key=CWbytearray(b'2b 7e 15 16 28 ae d2 a6 ab f7 15 88 09 cf 4f 3c')),
#   Trace(wave=array([-0.21337891, -0.14428711, -0.06201172, ...,  0.05615234,
#           0.07055664,  0.10131836]), textin=CWbytearray(b'ff 35 ac 4b 24 3b a0 07 81 21 b9 35 dd b8 86 66'), textout=CWbytearray(b'80 e3 cb 82 f9 d9 64 9b 02 df e1 06 95 f3 3d bc'), key=CWbytearray(b'2b 7e 15 16 28 ae d2 a6 ab f7 15 88 09 cf 4f 3c')),
#   Trace(wave=array([-0.21166992, -0.1328125 , -0.06274414, ...,  0.05761719,
#           0.07617188,  0.10742188]), textin=CWbytearray(b'ff 58 d6 36 c0 d7 2f 9e 92 bb e1 24 32 9f ec 7f'), textout=CWbytearray(b'c3 f2 f7 9a 38 b9 13 e1 88 3c ed 18 05 9e 92 a7'), key=CWbytearray(b'2b 7e 15 16 28 ae d2 a6 ab f7 15 88 09 cf 4f 3c')),
#   Trace(wave=array([-0.22509766, -0.12866211, -0.05639648, ...,  0.06469727,
#           0.07275391,  0.11206055]), textin=CWbytearray(b'ff 10 0d 77 d2 13 5d 1d d2 e2 ff 6f 79 cd 66 db'), textout=CWbytearray(b'74 d8 95 76 1c bd 90 44 cc 60 1f 36 6d 2f c4 bf'), key=CWbytearray(b'2b 7e 15 16 28 ae d2 a6 ab f7 15 88 09 cf 4f 3c'))],
#  [Trace(wave=array([-0.20727539, -0.13500977, -0.05444336, ...,  0.07128906,
#           0.06665039,  0.10058594]), textin=CWbytearray(b'00 7f 2c 66 3b 56 6b 6b 99 d1 83 14 1a 58 1a 77'), textout=CWbytearray(b'a8 ce 0b d6 34 07 e4 a5 2b 25 77 f0 c3 65 7c 7c'), key=CWbytearray(b'2b 7e 15 16 28 ae d2 a6 ab f7 15 88 09 cf 4f 3c')),
#   Trace(wave=array([-0.21508789, -0.1315918 , -0.05371094, ...,  0.05957031,
#           0.07519531,  0.109375  ]), textin=CWbytearray(b'00 68 31 05 b6 e8 84 0d bd ae aa ae fe ec 8d 40'), textout=CWbytearray(b'79 cf 5a 38 17 e1 21 58 54 68 34 90 09 ca aa 78'), key=CWbytearray(b'2b 7e 15 16 28 ae d2 a6 ab f7 15 88 09 cf 4f 3c')),
#   Trace(wave=array([-0.21850586, -0.12402344, -0.05859375, ...,  0.06860352,
#           0.06396484,  0.10864258]), textin=CWbytearray(b'00 53 ff 89 74 c4 9a 33 0d 50 d4 c1 11 0b 68 3f'), textout=CWbytearray(b'c6 bc 38 95 ad 50 f1 c3 ea 3b e1 8a 5e e8 fa d5'), key=CWbytearray(b'2b 7e 15 16 28 ae d2 a6 ab f7 15 88 09 cf 4f 3c')),
#   Trace(wave=array([-0.20800781, -0.14038086, -0.07128906, ...,  0.06030273,
#           0.07373047,  0.09838867]), textin=CWbytearray(b'00 3d 0d d6 78 da 47 cc a8 88 67 51 9f bd c8 f2'), textout=CWbytearray(b'88 b4 b0 21 70 19 e6 0c 94 35 ab 75 e4 0b 6f 3d'), key=CWbytearray(b'2b 7e 15 16 28 ae d2 a6 ab f7 15 88 09 cf 4f 3c')),
#   Trace(wave=array([-0.21435547, -0.14428711, -0.06616211, ...,  0.05810547,
#           0.078125  ,  0.09960938]), textin=CWbytearray(b'00 c9 00 03 1b 0c 7a 60 b8 b7 47 92 13 08 04 85'), textout=CWbytearray(b'a4 ac c6 f8 20 a4 0c 3a 2c 41 56 21 88 fc 33 6f'), key=CWbytearray(b'2b 7e 15 16 28 ae d2 a6 ab f7 15 88 09 cf 4f 3c')),
#   Trace(wave=array([-0.21459961, -0.10449219, -0.06518555, ...,  0.06713867,
#           0.07275391,  0.11083984]), textin=CWbytearray(b'00 93 5d b7 d3 bb f4 92 7f c7 cf 52 65 bc b9 1f'), textout=CWbytearray(b'ad fd 36 78 c6 78 f5 71 3b 27 66 27 66 94 f1 3e'), key=CWbytearray(b'2b 7e 15 16 28 ae d2 a6 ab f7 15 88 09 cf 4f 3c')),
#   Trace(wave=array([-0.21069336, -0.12353516, -0.07299805, ...,  0.05810547,
#           0.07470703,  0.09716797]), textin=CWbytearray(b'00 a5 75 37 b2 bf 98 bf 7b 6d b7 3c 15 78 94 24'), textout=CWbytearray(b'25 18 9c 00 8f c1 ff bb 18 79 f5 27 56 5a 49 d1'), key=CWbytearray(b'2b 7e 15 16 28 ae d2 a6 ab f7 15 88 09 cf 4f 3c')),
#   Trace(wave=array([-0.19140625, -0.14868164, -0.06811523, ...,  0.04736328,
#           0.07226562,  0.09936523]), textin=CWbytearray(b'00 2f 52 e6 c4 b9 88 57 b7 ba 46 fd 91 a3 fb 1b'), textout=CWbytearray(b'4a ce 4b 1f a3 26 8c dc 0d ba b8 fb a7 d4 5f 8a'), key=CWbytearray(b'2b 7e 15 16 28 ae d2 a6 ab f7 15 88 09 cf 4f 3c')),
#   Trace(wave=array([-0.22216797, -0.14038086, -0.05566406, ...,  0.05981445,
#           0.06518555,  0.09643555]), textin=CWbytearray(b'00 e8 d8 43 8e ac 3b cd 41 6b 17 67 55 6a 13 ed'), textout=CWbytearray(b'02 55 e0 bd d4 83 5f eb d4 01 08 30 9b bf d5 4d'), key=CWbytearray(b'2b 7e 15 16 28 ae d2 a6 ab f7 15 88 09 cf 4f 3c')),
#   Trace(wave=array([-0.20751953, -0.13183594, -0.05249023, ...,  0.06103516,
#           0.07080078,  0.10888672]), textin=CWbytearray(b'00 57 97 2c 3e 8c 23 6c 02 bb 12 1b 1c 35 ea 80'), textout=CWbytearray(b'd8 ff 5a 59 d7 4d f9 cd 63 35 85 15 ec 9f 86 65'), key=CWbytearray(b'2b 7e 15 16 28 ae d2 a6 ab f7 15 88 09 cf 4f 3c')),
#   Trace(wave=array([-0.21313477, -0.14331055, -0.06860352, ...,  0.06225586,
#           0.07250977,  0.10522461]), textin=CWbytearray(b'00 11 2e 53 c0 ce 56 f2 55 0c eb 82 d3 aa b8 d3'), textout=CWbytearray(b'17 97 d8 b7 c0 fe 42 4e 27 c5 f2 15 43 e4 31 4c'), key=CWbytearray(b'2b 7e 15 16 28 ae d2 a6 ab f7 15 88 09 cf 4f 3c')),
#   Trace(wave=array([-0.20727539, -0.12573242, -0.05981445, ...,  0.06298828,
#           0.07397461,  0.10253906]), textin=CWbytearray(b'00 17 a8 d3 59 b8 14 de 9d 52 4f 00 00 29 25 50'), textout=CWbytearray(b'76 40 55 f4 2f ee 9e 60 c7 ce 3b e1 69 64 8e 44'), key=CWbytearray(b'2b 7e 15 16 28 ae d2 a6 ab f7 15 88 09 cf 4f 3c')),
#   Trace(wave=array([-0.19946289, -0.14501953, -0.05834961, ...,  0.06347656,
#           0.06567383,  0.09863281]), textin=CWbytearray(b'00 7d 0c fc 13 2d e1 68 8c 1a ae ab b3 3e e5 0f'), textout=CWbytearray(b'9b 90 54 99 f3 cd 0b 8e 61 ac ae e5 ec 35 60 ec'), key=CWbytearray(b'2b 7e 15 16 28 ae d2 a6 ab f7 15 88 09 cf 4f 3c')),
#   Trace(wave=array([-0.21582031, -0.13989258, -0.05737305, ...,  0.06274414,
#           0.07299805,  0.10839844]), textin=CWbytearray(b'00 c3 6c b8 e7 01 0b 30 8f a3 8e 38 53 6a d9 ad'), textout=CWbytearray(b'a9 ac e5 ec 27 3e e4 d7 7e 54 ea 04 97 68 a4 73'), key=CWbytearray(b'2b 7e 15 16 28 ae d2 a6 ab f7 15 88 09 cf 4f 3c')),
#   Trace(wave=array([-0.21484375, -0.13647461, -0.06323242, ...,  0.06640625,
#           0.06982422,  0.09594727]), textin=CWbytearray(b'00 cf 9d f8 44 ec 0f 68 57 7e a3 5a 16 b7 2d f2'), textout=CWbytearray(b'01 89 0d 83 9a 63 ee 12 4f 19 b9 71 8d cf 32 a7'), key=CWbytearray(b'2b 7e 15 16 28 ae d2 a6 ab f7 15 88 09 cf 4f 3c')),
#   Trace(wave=array([-0.20507812, -0.15307617, -0.05639648, ...,  0.05322266,
#           0.07983398,  0.09838867]), textin=CWbytearray(b'00 54 21 95 be c1 0c 46 17 9c dd b8 b6 9b cb 17'), textout=CWbytearray(b'b8 a7 a4 43 15 79 c1 00 64 cd d4 61 18 ee 6d ba'), key=CWbytearray(b'2b 7e 15 16 28 ae d2 a6 ab f7 15 88 09 cf 4f 3c')),
#   Trace(wave=array([-0.21655273, -0.14013672, -0.0625    , ...,  0.05615234,
#           0.0690918 ,  0.09741211]), textin=CWbytearray(b'00 37 10 88 a2 a4 58 01 0f 1a d3 63 4f 0d a4 19'), textout=CWbytearray(b'14 a5 50 15 a9 d9 2a 97 e6 84 1d 0c 6c d3 e1 dc'), key=CWbytearray(b'2b 7e 15 16 28 ae d2 a6 ab f7 15 88 09 cf 4f 3c')),
#   Trace(wave=array([-0.20043945, -0.13500977, -0.05224609, ...,  0.04174805,
#           0.07226562,  0.10351562]), textin=CWbytearray(b'00 cc 48 49 8e b3 07 bf b7 bf 14 1c c8 91 9d a5'), textout=CWbytearray(b'd9 5f 57 e3 33 ce fb ce 55 d1 9a fe 04 e4 dd 3a'), key=CWbytearray(b'2b 7e 15 16 28 ae d2 a6 ab f7 15 88 09 cf 4f 3c')),
#   Trace(wave=array([-0.21923828, -0.13256836, -0.05761719, ...,  0.06274414,
#           0.06347656,  0.11035156]), textin=CWbytearray(b'00 a0 de d4 f0 8e f6 55 65 c4 0a fe 9a e5 b6 93'), textout=CWbytearray(b'90 04 51 b2 73 e5 e0 bc 5f 55 e3 54 78 66 0e aa'), key=CWbytearray(b'2b 7e 15 16 28 ae d2 a6 ab f7 15 88 09 cf 4f 3c')),
#   Trace(wave=array([-0.1875    , -0.13574219, -0.06787109, ...,  0.0546875 ,
#           0.07495117,  0.10644531]), textin=CWbytearray(b'00 6d 2e d6 18 92 e2 db 62 31 1b 45 21 6d 2d 37'), textout=CWbytearray(b'5a e0 72 ff 1a ba fe 3a a4 45 17 de 42 92 0c b5'), key=CWbytearray(b'2b 7e 15 16 28 ae d2 a6 ab f7 15 88 09 cf 4f 3c')),
#   Trace(wave=array([-0.21142578, -0.13891602, -0.03613281, ...,  0.06298828,
#           0.06958008,  0.10009766]), textin=CWbytearray(b'00 c4 8a 69 98 8a ff 7f 9f db c2 c8 06 67 f1 0a'), textout=CWbytearray(b'5b 2f 75 bd 2c 52 ee c7 d4 d4 81 c9 0d c2 3f ef'), key=CWbytearray(b'2b 7e 15 16 28 ae d2 a6 ab f7 15 88 09 cf 4f 3c')),
#   Trace(wave=array([-0.2331543 , -0.13964844, -0.046875  , ...,  0.06469727,
#           0.07568359,  0.10498047]), textin=CWbytearray(b'00 08 a5 0c 89 b0 5d fc 0e 41 81 39 78 80 e8 2b'), textout=CWbytearray(b'c7 e5 7c ae 31 8f 7f a2 79 a4 ed c9 8a c9 68 7f'), key=CWbytearray(b'2b 7e 15 16 28 ae d2 a6 ab f7 15 88 09 cf 4f 3c')),
#   Trace(wave=array([-0.203125  , -0.14892578, -0.06518555, ...,  0.0534668 ,
#           0.06689453,  0.1105957 ]), textin=CWbytearray(b'00 63 9a 04 29 31 66 18 05 15 63 e2 98 81 6c 05'), textout=CWbytearray(b'98 28 3c 08 1e 04 b5 03 d3 d6 df c4 fa ac 02 3e'), key=CWbytearray(b'2b 7e 15 16 28 ae d2 a6 ab f7 15 88 09 cf 4f 3c')),
#   Trace(wave=array([-0.20874023, -0.12426758, -0.05395508, ...,  0.06738281,
#           0.07055664,  0.10571289]), textin=CWbytearray(b'00 87 1e 81 c4 ea 2d 9a bf 11 51 f4 65 7f c0 85'), textout=CWbytearray(b'cb 2a 88 07 be b5 65 77 c6 f2 44 65 4d bc 46 dd'), key=CWbytearray(b'2b 7e 15 16 28 ae d2 a6 ab f7 15 88 09 cf 4f 3c')),
#   Trace(wave=array([-0.19775391, -0.14306641, -0.06054688, ...,  0.07836914,
#           0.07592773,  0.09692383]), textin=CWbytearray(b'00 a8 ce cf 9c 1f c3 38 7f 64 bd 83 95 c7 c9 f9'), textout=CWbytearray(b'21 45 5a de 3d c5 71 9a 36 09 6b 60 f7 52 cb d2'), key=CWbytearray(b'2b 7e 15 16 28 ae d2 a6 ab f7 15 88 09 cf 4f 3c')),
#   Trace(wave=array([-0.20727539, -0.14233398, -0.05859375, ...,  0.05981445,
#           0.07299805,  0.10888672]), textin=CWbytearray(b'00 ef 1a 8a 6a d9 e2 fa 06 c5 f2 4d 65 10 42 a5'), textout=CWbytearray(b'e2 4e 26 c9 87 ab a9 0a 10 4d a2 eb 02 af 80 04'), key=CWbytearray(b'2b 7e 15 16 28 ae d2 a6 ab f7 15 88 09 cf 4f 3c')),
#   Trace(wave=array([-0.21020508, -0.13330078, -0.0612793 , ...,  0.0690918 ,
#           0.07104492,  0.11035156]), textin=CWbytearray(b'00 14 89 05 2d 08 74 eb 31 5c 86 d5 93 f6 76 8f'), textout=CWbytearray(b'b7 e1 0f 9f 61 90 fb ee d0 89 95 a6 cb 8f 79 c9'), key=CWbytearray(b'2b 7e 15 16 28 ae d2 a6 ab f7 15 88 09 cf 4f 3c')),
#   Trace(wave=array([-0.21411133, -0.14086914, -0.06054688, ...,  0.06323242,
#           0.06494141,  0.09741211]), textin=CWbytearray(b'00 cd 2b a8 99 a8 25 65 55 86 91 94 b2 76 22 42'), textout=CWbytearray(b'80 72 56 45 4a e2 e3 1a 3d a1 fe 78 82 85 cd 00'), key=CWbytearray(b'2b 7e 15 16 28 ae d2 a6 ab f7 15 88 09 cf 4f 3c')),
#   Trace(wave=array([-0.21435547, -0.12817383, -0.05786133, ...,  0.06616211,
#           0.0769043 ,  0.1027832 ]), textin=CWbytearray(b'00 78 00 1c eb 59 e2 07 9f 08 a6 b3 21 b4 be 41'), textout=CWbytearray(b'52 cf 6f 40 31 fa 60 2a d3 14 9c 30 1d e6 e3 39'), key=CWbytearray(b'2b 7e 15 16 28 ae d2 a6 ab f7 15 88 09 cf 4f 3c')),
#   Trace(wave=array([-0.20263672, -0.13745117, -0.06201172, ...,  0.06445312,
#           0.0703125 ,  0.10351562]), textin=CWbytearray(b'00 79 3e 89 08 d0 92 bd ec 73 b5 80 bc ff 5c d3'), textout=CWbytearray(b'9d 2e 12 2b 5d 61 4f a5 03 90 b4 68 03 d7 c3 52'), key=CWbytearray(b'2b 7e 15 16 28 ae d2 a6 ab f7 15 88 09 cf 4f 3c')),
#   Trace(wave=array([-0.21386719, -0.12890625, -0.06152344, ...,  0.0625    ,
#           0.0690918 ,  0.09692383]), textin=CWbytearray(b'00 9d 93 74 42 cb bc 9a 0c 1e 5a 27 cc 75 30 da'), textout=CWbytearray(b'7e 51 66 d1 90 a8 a8 c9 a1 04 7a e1 5c d8 69 0d'), key=CWbytearray(b'2b 7e 15 16 28 ae d2 a6 ab f7 15 88 09 cf 4f 3c')),
#   Trace(wave=array([-0.21240234, -0.14746094, -0.0625    , ...,  0.06298828,
#           0.07104492,  0.10083008]), textin=CWbytearray(b'00 10 ba 94 43 45 09 3f 5d 3d a2 f3 2b 1f ba 8d'), textout=CWbytearray(b'65 2e f8 52 07 cb 92 2b 31 7b ae 3d 8c a9 e2 5f'), key=CWbytearray(b'2b 7e 15 16 28 ae d2 a6 ab f7 15 88 09 cf 4f 3c')),
#   Trace(wave=array([-0.18505859, -0.12670898, -0.06005859, ...,  0.0625    ,
#           0.07275391,  0.10644531]), textin=CWbytearray(b'00 d4 c0 48 02 60 8f 69 f2 a8 44 ea 29 50 7d 3b'), textout=CWbytearray(b'ff ab be 9e 93 ce 71 84 91 69 b2 40 9c dc f4 a4'), key=CWbytearray(b'2b 7e 15 16 28 ae d2 a6 ab f7 15 88 09 cf 4f 3c')),
#   Trace(wave=array([-0.21118164, -0.13720703, -0.06665039, ...,  0.06396484,
#           0.07666016,  0.10888672]), textin=CWbytearray(b'00 bf 38 d1 d6 01 fa b5 3f c4 f0 8d 83 83 c6 e0'), textout=CWbytearray(b'c3 6a 4d 6a 4b 12 ba 47 ee 05 94 a3 27 4d 99 5e'), key=CWbytearray(b'2b 7e 15 16 28 ae d2 a6 ab f7 15 88 09 cf 4f 3c')),
#   Trace(wave=array([-0.20996094, -0.13818359, -0.0402832 , ...,  0.06616211,
#           0.07714844,  0.1003418 ]), textin=CWbytearray(b'00 ce c7 b3 58 61 03 72 f5 ee 31 6c 47 c3 43 bd'), textout=CWbytearray(b'cc 89 44 42 1e db ca 5f e0 d3 9f f5 b3 d4 17 d7'), key=CWbytearray(b'2b 7e 15 16 28 ae d2 a6 ab f7 15 88 09 cf 4f 3c')),
#   Trace(wave=array([-0.22631836, -0.14501953, -0.0637207 , ...,  0.06616211,
#           0.06420898,  0.10888672]), textin=CWbytearray(b'00 e6 b4 0f c7 7d 47 92 72 db 6a ba b8 d1 b4 98'), textout=CWbytearray(b'4a 29 7e b8 97 74 61 30 67 94 b3 12 d7 71 06 c8'), key=CWbytearray(b'2b 7e 15 16 28 ae d2 a6 ab f7 15 88 09 cf 4f 3c')),
#   Trace(wave=array([-0.20410156, -0.13500977, -0.06542969, ...,  0.05932617,
#           0.06542969,  0.10766602]), textin=CWbytearray(b'00 f8 40 4b 0e c6 2e cd 19 e0 77 10 12 9a 21 61'), textout=CWbytearray(b'33 b1 ae b1 fb 3a 22 58 13 55 5e 72 84 40 52 a0'), key=CWbytearray(b'2b 7e 15 16 28 ae d2 a6 ab f7 15 88 09 cf 4f 3c')),
#   Trace(wave=array([-0.21875   , -0.13037109, -0.06323242, ...,  0.07080078,
#           0.06762695,  0.10986328]), textin=CWbytearray(b'00 d3 b0 5d ee 65 cf db dc 18 f8 0a 3f f1 dc cb'), textout=CWbytearray(b'75 ae ec 7d 27 1c 4f 74 df e9 1a 87 f4 04 c7 e4'), key=CWbytearray(b'2b 7e 15 16 28 ae d2 a6 ab f7 15 88 09 cf 4f 3c')),
#   Trace(wave=array([-0.21264648, -0.14013672, -0.06323242, ...,  0.06933594,
#           0.06176758,  0.09423828]), textin=CWbytearray(b'00 f8 dc 98 71 ee f2 68 9c 23 2d 7e 43 20 24 cd'), textout=CWbytearray(b'36 78 de ef 60 8a 29 88 de e8 40 6a 61 c4 51 e7'), key=CWbytearray(b'2b 7e 15 16 28 ae d2 a6 ab f7 15 88 09 cf 4f 3c')),
#   Trace(wave=array([-0.1809082 , -0.1315918 , -0.05493164, ...,  0.05981445,
#           0.0690918 ,  0.10107422]), textin=CWbytearray(b'00 7b d7 12 a6 1f 81 ed 0e ef ca 31 44 b3 26 96'), textout=CWbytearray(b'a6 8c 39 48 58 f3 59 ac 81 c7 45 fa 38 63 4f a7'), key=CWbytearray(b'2b 7e 15 16 28 ae d2 a6 ab f7 15 88 09 cf 4f 3c')),
#   Trace(wave=array([-0.20800781, -0.140625  , -0.06811523, ...,  0.06396484,
#           0.06787109,  0.09838867]), textin=CWbytearray(b'00 43 bc 0e 65 4b 73 41 61 2c 42 a3 41 ff 07 73'), textout=CWbytearray(b'a2 3a ad fb e5 00 3b ef 9f 8d d0 f7 d8 6e 7e 02'), key=CWbytearray(b'2b 7e 15 16 28 ae d2 a6 ab f7 15 88 09 cf 4f 3c')),
#   Trace(wave=array([-0.21337891, -0.13232422, -0.0534668 , ...,  0.0637207 ,
#           0.08764648,  0.09887695]), textin=CWbytearray(b'00 c2 25 c7 ac 6d a2 99 13 83 5c ac 69 ce 0f 57'), textout=CWbytearray(b'd7 bb cc 50 e7 5b 0f 4a 7b 8d 36 1a 4a 5b 9a 8b'), key=CWbytearray(b'2b 7e 15 16 28 ae d2 a6 ab f7 15 88 09 cf 4f 3c')),
#   Trace(wave=array([-0.20629883, -0.13867188, -0.05810547, ...,  0.06469727,
#           0.06689453,  0.10205078]), textin=CWbytearray(b'00 45 43 ee 0f 4f 57 53 07 1e 1a 9a 22 e1 f4 69'), textout=CWbytearray(b'ab 47 8d ca c4 4f c9 9e 90 57 cd f0 80 bc 0e 72'), key=CWbytearray(b'2b 7e 15 16 28 ae d2 a6 ab f7 15 88 09 cf 4f 3c')),
#   Trace(wave=array([-0.21386719, -0.15307617, -0.06396484, ...,  0.05737305,
#           0.07177734,  0.10839844]), textin=CWbytearray(b'00 18 a5 91 7f 9c 76 42 10 2f 9d 9e a8 ad 5a d1'), textout=CWbytearray(b'62 e1 ef 34 c7 62 fb 41 3b 90 dd 59 33 57 8c 1a'), key=CWbytearray(b'2b 7e 15 16 28 ae d2 a6 ab f7 15 88 09 cf 4f 3c')),
#   Trace(wave=array([-0.22119141, -0.13500977, -0.06347656, ...,  0.06152344,
#           0.06542969,  0.10375977]), textin=CWbytearray(b'00 9a 8a 6a c7 bd e5 49 2e ed f9 98 30 ff fd b4'), textout=CWbytearray(b'b5 e3 04 1c 2d 15 32 f5 c3 c0 2b 54 40 18 cf 1a'), key=CWbytearray(b'2b 7e 15 16 28 ae d2 a6 ab f7 15 88 09 cf 4f 3c')),
#   Trace(wave=array([-0.2277832 , -0.13183594, -0.06054688, ...,  0.06982422,
#           0.06518555,  0.09277344]), textin=CWbytearray(b'00 8b ca 80 f1 06 cd 78 89 8a 0a f2 d9 4d 11 85'), textout=CWbytearray(b'5d 98 78 71 72 55 5c 27 7e e5 c3 d8 fd 93 9c 75'), key=CWbytearray(b'2b 7e 15 16 28 ae d2 a6 ab f7 15 88 09 cf 4f 3c')),
#   Trace(wave=array([-0.20532227, -0.1315918 , -0.06396484, ...,  0.06738281,
#           0.07763672,  0.10913086]), textin=CWbytearray(b'00 cc b3 06 3a 50 bf 26 cf c3 62 2b 8e 33 32 cd'), textout=CWbytearray(b'4a a7 ce 9a 52 1c a7 c9 ce 13 f0 11 ad 04 74 59'), key=CWbytearray(b'2b 7e 15 16 28 ae d2 a6 ab f7 15 88 09 cf 4f 3c')),
#   Trace(wave=array([-0.20605469, -0.13354492, -0.04541016, ...,  0.06762695,
#           0.06787109,  0.10668945]), textin=CWbytearray(b'00 41 ba b8 f1 7c 3b ad 9c 1b a7 00 30 75 22 f4'), textout=CWbytearray(b'85 10 87 47 c9 3f 8c 5e 3a ad 88 68 c6 9b 58 a1'), key=CWbytearray(b'2b 7e 15 16 28 ae d2 a6 ab f7 15 88 09 cf 4f 3c')),
#   Trace(wave=array([-0.21289062, -0.14404297, -0.0715332 , ...,  0.05737305,
#           0.07006836,  0.09667969]), textin=CWbytearray(b'00 9c 13 0d 52 85 8a c0 fb 31 d1 bc 3e e4 e7 82'), textout=CWbytearray(b'0a 11 2e bb 5e cc 98 7d 1c 74 82 e4 e5 e7 0c b1'), key=CWbytearray(b'2b 7e 15 16 28 ae d2 a6 ab f7 15 88 09 cf 4f 3c')),
#   Trace(wave=array([-0.21557617, -0.14501953, -0.06103516, ...,  0.05786133,
#           0.07446289,  0.10107422]), textin=CWbytearray(b'00 14 8b f6 54 e5 b2 d5 1a e4 42 f5 a4 3b cc 65'), textout=CWbytearray(b'bf 60 a6 71 05 22 0b c9 d7 ff 6e 65 bd 92 02 25'), key=CWbytearray(b'2b 7e 15 16 28 ae d2 a6 ab f7 15 88 09 cf 4f 3c')),
#   Trace(wave=array([-0.20605469, -0.13720703, -0.04223633, ...,  0.06616211,
#           0.06054688,  0.11181641]), textin=CWbytearray(b'00 80 7e de 4e 7b e3 66 dd 41 36 0a bd 67 97 5e'), textout=CWbytearray(b'0e 2c 41 37 c5 11 7c 5f b5 f2 48 6c c6 b0 f2 11'), key=CWbytearray(b'2b 7e 15 16 28 ae d2 a6 ab f7 15 88 09 cf 4f 3c')),
#   Trace(wave=array([-0.22094727, -0.14135742, -0.06298828, ...,  0.06103516,
#           0.06860352,  0.10864258]), textin=CWbytearray(b'00 9d ac 76 c6 87 03 7e a1 d8 e6 a4 73 1d 3e fd'), textout=CWbytearray(b'f1 cb 48 d2 5b 64 57 89 20 5e 62 b2 b6 5d c9 1b'), key=CWbytearray(b'2b 7e 15 16 28 ae d2 a6 ab f7 15 88 09 cf 4f 3c')),
#   Trace(wave=array([-0.234375  , -0.13134766, -0.05737305, ...,  0.06103516,
#           0.06567383,  0.09936523]), textin=CWbytearray(b'00 17 1e 77 9c 2b 64 5b 4d 34 28 b1 91 ea 17 d4'), textout=CWbytearray(b'ff b9 1f b4 49 aa a3 08 02 1b 94 bc 67 20 14 6d'), key=CWbytearray(b'2b 7e 15 16 28 ae d2 a6 ab f7 15 88 09 cf 4f 3c'))])

# %% [markdown]
# We should have two different lists. Whether we sent 0xFF or 0x00 was random, so these lists likely won't be evenly dispersed. Next, we'll want to take an average of each group (make sure you take an average of each trace at each point! We don't want an average of the traces in time), which will help smooth out any outliers and also fix our issue of having a different number of traces for each group.
#
# The easiest way to accomplish this will be to use `np.mean()`, which can take a list as an argument. You'll need to specify the `axis` parameter as well, to ensure you take the correct dimension. Check the resulting size to make sure you still have traces of the same length as one input - the following block shows how you can verify that, assuming you used `one_avg` as the average.

# %%
trace_length = len(one_list[0].wave)
print("Traces had original sample length of %d"%trace_length)

one_avg = list(np.mean([one_item.wave for one_item in one_list], 0))
zero_avg = list(np.mean([zero_item.wave for zero_item in zero_list], 0))

if len(one_avg) != trace_length:
    raise ValueError("Average length is only %d - check you did correct dimensions!"%len(one_avg))
# Out:
# Traces had original sample length of 5000

# %% [markdown]
# Finally, subtract the two averages and plot the resulting data:

# %%
total_avg = np.subtract(one_avg, zero_avg)

# %%
plot_scope_traces([[total_avg]], settings, titles=["Total_Avg"])

# %% [markdown]
# You should see a very distinct trace near the beginning of the plot, meaning that the data being manipulated in the target device is visible in its power trace! Again, there's a lot of room to explore here:
#
# * Try setting multiple bytes to 0x00 and 0xFF.
# * Try using smaller hamming weight differences. Is the spike still distinct? What about if you capture more traces?
# * We focused on the first byte here. Try putting the difference plots for multiple different bytes on the same plot.
# * The target is running AES here. Can you get the spikes to appear in different places if you set a byte in a later round of AES (say round 5) to 0x00 or 0xFF?
#
# One other note that might trip you out: rememeber you are measuring the voltage at the input to ChipWhisperer, which is measured across a shunt resistor. The end result of this is that a lower voltage actually means more power. So you might see the spikes flipped from the "expected" direction based on a 1 taking more power than a 0.

# %% [markdown]
# ---
# 1. Setting multiple bytes to 0x00 and 0xFF

# %% [markdown]
# ### With Device

# %%
bit_length = 3
trace_array = generate_traces(3000, bit_length)
# Out:
# Capturing traces:   0%|          | 0/3000 [00:00<?, ?it/s]

# %%
save_data('lab_3_1_multiple_byte_traces', trace_array, settings)
# Out:
# Directory already exists at "/Users/xcrbox/Desktop/2026-eCTF/chipwhisperer/jupyter/courses/sca101/data/lab_3_1_multiple_byte_traces"

# %% [markdown]
# ### Without Device

# %%
trace_array, settings = import_data('lab_3_1_multiple_byte_traces')
# Out:
# Number of Traces: 3000

# %%
import math

bit_length = 3
num_of_lists = 1 << bit_length
sorted_lists = []
two_holder = 1
index_sum = 0

for i in range(num_of_lists):
    sorted_lists.append([])

for i in range(len(trace_array)):
    two_holder = 1
    index_sum = 0

    for j in range(bit_length):
        index_sum += (trace_array[i].textin[j] & 0x01) << j

    sorted_lists[index_sum].append(trace_array[i])

# %%
print(len(sorted_lists))
# Out:
# 8

# %%
trace_length = len(sorted_lists[0][0].wave)
sorted_avgs = []

for i in range(num_of_lists):
    sorted_avgs.append(list(np.mean([sorted_item.wave for sorted_item in sorted_lists[i]], 0)))

total_avgs = []

for i in range(1, num_of_lists):
    total_avgs.append((np.subtract(sorted_avgs[i], sorted_avgs[0]), str(i), None))

# %%
plot_scope_traces([total_avgs], settings, titles=["Total_Avgs"])

# %%
scope.dis()
target.dis()

# %% [markdown]
# ---
# <small>NO-FUN DISCLAIMER: This material is Copyright (C) NewAE Technology Inc., 2015-2020. ChipWhisperer is a trademark of NewAE Technology Inc., claimed in all jurisdictions, and registered in at least the United States of America, European Union, and Peoples Republic of China.
#
# Tutorials derived from our open-source work must be released under the associated open-source license, and notice of the source must be *clearly displayed*. Only original copyright holders may license or authorize other distribution - while NewAE Technology Inc. holds the copyright for many tutorials, the github repository includes community contributions which we cannot license under special terms and **must** be maintained as an open-source release. Please contact us for special permissions (where possible).
#
# THE SOFTWARE IS PROVIDED "AS IS", WITHOUT WARRANTY OF ANY KIND, EXPRESS OR IMPLIED, INCLUDING BUT NOT LIMITED TO THE WARRANTIES OF MERCHANTABILITY, FITNESS FOR A PARTICULAR PURPOSE AND NONINFRINGEMENT. IN NO EVENT SHALL THE AUTHORS OR COPYRIGHT HOLDERS BE LIABLE FOR ANY CLAIM, DAMAGES OR OTHER LIABILITY, WHETHER IN AN ACTION OF CONTRACT, TORT OR OTHERWISE, ARISING FROM, OUT OF OR IN CONNECTION WITH THE SOFTWARE OR THE USE OR OTHER DEALINGS IN THE SOFTWARE.</small>
