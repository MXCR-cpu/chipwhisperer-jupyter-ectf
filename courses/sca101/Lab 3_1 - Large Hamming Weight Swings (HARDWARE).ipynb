# %% [markdown]
# # Part 3, Topic 1: Large Hamming Weight Swings (HARDWARE)

# %% [markdown]
# ---
# **THIS IS NOT THE COMPLETE TUTORIAL - see file with `(MAIN)` in the name.**
#
# ---

# %% [markdown]
# First you'll need to select which hardware setup you have. You'll need to select a `SCOPETYPE`, a `PLATFORM`, and a `CRYPTO_TARGET`. `SCOPETYPE` can either be `'OPENADC'` for the CWLite/CW1200 or `'CWNANO'` for the CWNano. `PLATFORM` is the target device, with `'CWLITEARM'`/`'CW308_STM32F3'` being the best supported option, followed by `'CWLITEXMEGA'`/`'CW308_XMEGA'`, then by `'CWNANO'`. `CRYPTO_TARGET` selects the crypto implementation, with `'TINYAES128C'` working on all platforms. An alternative for `'CWLITEXMEGA'` targets is `'AVRCRYPTOLIB'`. For example:
#
# ```python
# SCOPETYPE = 'OPENADC'
# PLATFORM = 'CWLITEARM'
# CRYPTO_TARGET='TINYAES128C'
# SS_VER='SS_VER_2_1'
# ```

# %%
SCOPETYPE = 'OPENADC'
PLATFORM = 'CW312_SAM4S'
CRYPTO_TARGET='TINYAES128C'
SS_VER='SS_VER_2_1'

# %% [markdown]
# The following code will build the firmware for the target.

# %%
# %run "../../Setup_Scripts/Setup_Generic.ipynb"
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# File /var/folders/1s/yy2fj15x0jn7c5g4qr9r7kl00000gn/T/ipykernel_22242/2799263322.py:4
#       3 try:
# ----> 4     if not scope.connectStatus:
#       5         scope.con()
#
# NameError: name 'scope' is not defined
#
# During handling of the above exception, another exception occurred:
#
# USBErrorAccess                            Traceback (most recent call last)
# File /var/folders/1s/yy2fj15x0jn7c5g4qr9r7kl00000gn/T/ipykernel_22242/2799263322.py:7
#       5         scope.con()
#       6 except NameError:
# ----> 7     scope = cw.scope()
#       9 try:
#      10     if SS_VER == "SS_VER_2_1":
#
# File ~/Desktop/chipwhisperer/software/chipwhisperer/__init__.py:400, in scope(scope_type, name, sn, idProduct, bitstream, force, prog_speed, **kwargs)
#     398 rtn : scopes.ScopeTypes = scope_type()
#     399 try:
# --> 400     rtn.con(**kwargs)
#     401 except IOError:
#     402     scope_logger.error("ChipWhisperer error state detected. Resetting and retrying connection...")
#
# File ~/Desktop/chipwhisperer/software/chipwhisperer/capture/scopes/OpenADC.py:654, in OpenADC.con(self, sn, idProduct, bitstream, force, prog_speed, **kwargs)
#     650 self._saved_sn = sn
#     652 self.scopetype = OpenADCInterface_NAEUSBChip()
# --> 654 self.scopetype.con(sn, idProduct, bitstream, force, prog_speed, **kwargs)
#     655 self.sc = OpenADCInterface(self.scopetype.ser, self.scopetype.registers) # important to instantiate this before other FPGA components, since this does an FPGA reset
#     656 self.hwinfo = HWInformation(self.sc)
#
# File ~/Desktop/chipwhisperer/software/chipwhisperer/capture/scopes/openadc_interface/naeusbchip.py:65, in OpenADCInterface_NAEUSBChip.con(self, sn, idProduct, bitstream, force, prog_speed, registers, **kwargs)
#      63 else:
#      64     nae_products = [0xACE2, 0xACE3, 0xACE5, 0xACE6]
# ---> 65 found_id = self.ser.con(idProduct=nae_products, serial_number=sn, **kwargs)
#      66 if force:
#      67     self.fpga.eraseFPGA()
#
# File ~/Desktop/chipwhisperer/software/chipwhisperer/hardware/naeusb/naeusb.py:807, in NAEUSB.con(self, idProduct, connect_to_first, serial_number, hw_location, **kwargs)
#     802 def con(self, idProduct : Tuple[int]=(0xACE2,), connect_to_first : bool=False,
#     803     serial_number : Optional[str]=None, hw_location : Optional[Tuple[int, int]]=None, **kwargs) -> int:
#     804     """
#     805     Connect to device using default VID/PID
#     806     """
# --> 807     self.usbtx.open(idProduct=idProduct, serial_number=serial_number, connect_to_first=True, hw_location=hw_location)
#     810     self.snum=self.usbtx.sn
#     811     fwverraw = self.readFwVersion()
#
# File ~/Desktop/chipwhisperer/software/chipwhisperer/hardware/naeusb/naeusb.py:461, in NAEUSB_Backend.open(self, serial_number, idProduct, connect_to_first, hw_location)
#     459 self._usbdev = self.handle
#     460 if os.name == "nt" or sys.platform == "darwin":
# --> 461     self.handle.claimInterface(0)
#     463 self.sn = self.handle.getSerialNumber()
#     464 self.pid = self.device.getProductID()
#
# File ~/.virtualenvs/chipwhisperer/lib/python3.13/site-packages/usb1/__init__.py:1222, in USBDeviceHandle.claimInterface(self, interface)
#    1212 def claimInterface(self, interface):
#    1213     """
#    1214     Claim (= get exclusive access to) given interface number. Required to
#    1215     receive/send data.
#    (...)   1220         # handle.releaseInterface(0) gets automatically called
#    1221     """
# -> 1222     mayRaiseUSBError(
#    1223         libusb1.libusb_claim_interface(self.__handle, interface),
#    1224     )
#    1225     return _ReleaseInterface(self, interface)
#
# File ~/.virtualenvs/chipwhisperer/lib/python3.13/site-packages/usb1/__init__.py:129, in mayRaiseUSBError(value, __raiseUSBError)
#     123 def mayRaiseUSBError(
#     124         value,
#     125         # Avoid globals lookup on call to work during interpreter shutdown.
#     126         __raiseUSBError=raiseUSBError,
#     127     ):
#     128     if value < 0:
# --> 129         __raiseUSBError(value)
#     130     return value
#
# File ~/.virtualenvs/chipwhisperer/lib/python3.13/site-packages/usb1/__init__.py:121, in raiseUSBError(value, __STATUS_TO_EXCEPTION_DICT, __USBError)
#     115 def raiseUSBError(
#     116         value,
#     117         # Avoid globals lookup on call to work during interpreter shutdown.
#     118         __STATUS_TO_EXCEPTION_DICT=STATUS_TO_EXCEPTION_DICT,
#     119         __USBError=USBError,
#     120     ): # pylint: disable=dangerous-default-value
# --> 121     raise __STATUS_TO_EXCEPTION_DICT.get(value, __USBError)(value)
#
# USBErrorAccess: LIBUSB_ERROR_ACCESS [-3]
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# File /var/folders/1s/yy2fj15x0jn7c5g4qr9r7kl00000gn/T/ipykernel_22242/2799263322.py:4
#       3 try:
# ----> 4     if not scope.connectStatus:
#       5         scope.con()
#
# NameError: name 'scope' is not defined
#
# During handling of the above exception, another exception occurred:
#
# USBErrorAccess                            Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 get_ipython().run_line_magic('run', '"../../Setup_Scripts/Setup_Generic.ipynb"')
#
# File ~/.virtualenvs/chipwhisperer/lib/python3.13/site-packages/IPython/core/interactiveshell.py:2504, in InteractiveShell.run_line_magic(self, magic_name, line, _stack_depth)
#    2502     kwargs['local_ns'] = self.get_local_scope(stack_depth)
#    2503 with self.builtin_trap:
# -> 2504     result = fn(*args, **kwargs)
#    2506 # The code below prevents the output from being displayed
#    2507 # when using magics with decorator @output_can_be_silenced
#    2508 # when the last Python token in the expression is a ';'.
#    2509 if getattr(fn, magic.MAGIC_OUTPUT_CAN_BE_SILENCED, False):
#
# File ~/.virtualenvs/chipwhisperer/lib/python3.13/site-packages/IPython/core/magics/execution.py:749, in ExecutionMagics.run(self, parameter_s, runner, file_finder)
#     747     with preserve_keys(self.shell.user_ns, '__file__'):
#     748         self.shell.user_ns['__file__'] = filename
# --> 749         self.shell.safe_execfile_ipy(filename, raise_exceptions=True)
#     750     return
#     752 # Control the response to exit() calls made by the script being run
#
# File ~/.virtualenvs/chipwhisperer/lib/python3.13/site-packages/IPython/core/interactiveshell.py:2995, in InteractiveShell.safe_execfile_ipy(self, fname, shell_futures, raise_exceptions)
#    2993 result = self.run_cell(cell, silent=True, shell_futures=shell_futures)
#    2994 if raise_exceptions:
# -> 2995     result.raise_error()
#    2996 elif not result.success:
#    2997     break
#
# File ~/.virtualenvs/chipwhisperer/lib/python3.13/site-packages/IPython/core/interactiveshell.py:326, in ExecutionResult.raise_error(self)
#     324     raise self.error_before_exec
#     325 if self.error_in_exec is not None:
# --> 326     raise self.error_in_exec
#
#     [... skipping hidden 1 frame]
#
# File /var/folders/1s/yy2fj15x0jn7c5g4qr9r7kl00000gn/T/ipykernel_22242/2799263322.py:7
#       5         scope.con()
#       6 except NameError:
# ----> 7     scope = cw.scope()
#       9 try:
#      10     if SS_VER == "SS_VER_2_1":
#
# File ~/Desktop/chipwhisperer/software/chipwhisperer/__init__.py:400, in scope(scope_type, name, sn, idProduct, bitstream, force, prog_speed, **kwargs)
#     398 rtn : scopes.ScopeTypes = scope_type()
#     399 try:
# --> 400     rtn.con(**kwargs)
#     401 except IOError:
#     402     scope_logger.error("ChipWhisperer error state detected. Resetting and retrying connection...")
#
# File ~/Desktop/chipwhisperer/software/chipwhisperer/capture/scopes/OpenADC.py:654, in OpenADC.con(self, sn, idProduct, bitstream, force, prog_speed, **kwargs)
#     650 self._saved_sn = sn
#     652 self.scopetype = OpenADCInterface_NAEUSBChip()
# --> 654 self.scopetype.con(sn, idProduct, bitstream, force, prog_speed, **kwargs)
#     655 self.sc = OpenADCInterface(self.scopetype.ser, self.scopetype.registers) # important to instantiate this before other FPGA components, since this does an FPGA reset
#     656 self.hwinfo = HWInformation(self.sc)
#
# File ~/Desktop/chipwhisperer/software/chipwhisperer/capture/scopes/openadc_interface/naeusbchip.py:65, in OpenADCInterface_NAEUSBChip.con(self, sn, idProduct, bitstream, force, prog_speed, registers, **kwargs)
#      63 else:
#      64     nae_products = [0xACE2, 0xACE3, 0xACE5, 0xACE6]
# ---> 65 found_id = self.ser.con(idProduct=nae_products, serial_number=sn, **kwargs)
#      66 if force:
#      67     self.fpga.eraseFPGA()
#
# File ~/Desktop/chipwhisperer/software/chipwhisperer/hardware/naeusb/naeusb.py:807, in NAEUSB.con(self, idProduct, connect_to_first, serial_number, hw_location, **kwargs)
#     802 def con(self, idProduct : Tuple[int]=(0xACE2,), connect_to_first : bool=False,
#     803     serial_number : Optional[str]=None, hw_location : Optional[Tuple[int, int]]=None, **kwargs) -> int:
#     804     """
#     805     Connect to device using default VID/PID
#     806     """
# --> 807     self.usbtx.open(idProduct=idProduct, serial_number=serial_number, connect_to_first=True, hw_location=hw_location)
#     810     self.snum=self.usbtx.sn
#     811     fwverraw = self.readFwVersion()
#
# File ~/Desktop/chipwhisperer/software/chipwhisperer/hardware/naeusb/naeusb.py:461, in NAEUSB_Backend.open(self, serial_number, idProduct, connect_to_first, hw_location)
#     459 self._usbdev = self.handle
#     460 if os.name == "nt" or sys.platform == "darwin":
# --> 461     self.handle.claimInterface(0)
#     463 self.sn = self.handle.getSerialNumber()
#     464 self.pid = self.device.getProductID()
#
# File ~/.virtualenvs/chipwhisperer/lib/python3.13/site-packages/usb1/__init__.py:1222, in USBDeviceHandle.claimInterface(self, interface)
#    1212 def claimInterface(self, interface):
#    1213     """
#    1214     Claim (= get exclusive access to) given interface number. Required to
#    1215     receive/send data.
#    (...)   1220         # handle.releaseInterface(0) gets automatically called
#    1221     """
# -> 1222     mayRaiseUSBError(
#    1223         libusb1.libusb_claim_interface(self.__handle, interface),
#    1224     )
#    1225     return _ReleaseInterface(self, interface)
#
# File ~/.virtualenvs/chipwhisperer/lib/python3.13/site-packages/usb1/__init__.py:129, in mayRaiseUSBError(value, __raiseUSBError)
#     123 def mayRaiseUSBError(
#     124         value,
#     125         # Avoid globals lookup on call to work during interpreter shutdown.
#     126         __raiseUSBError=raiseUSBError,
#     127     ):
#     128     if value < 0:
# --> 129         __raiseUSBError(value)
#     130     return value
#
# File ~/.virtualenvs/chipwhisperer/lib/python3.13/site-packages/usb1/__init__.py:121, in raiseUSBError(value, __STATUS_TO_EXCEPTION_DICT, __USBError)
#     115 def raiseUSBError(
#     116         value,
#     117         # Avoid globals lookup on call to work during interpreter shutdown.
#     118         __STATUS_TO_EXCEPTION_DICT=STATUS_TO_EXCEPTION_DICT,
#     119         __USBError=USBError,
#     120     ): # pylint: disable=dangerous-default-value
# --> 121     raise __STATUS_TO_EXCEPTION_DICT.get(value, __USBError)(value)
#
# USBErrorAccess: LIBUSB_ERROR_ACCESS [-3]

# %%
# %%bash -s "$PLATFORM" "$CRYPTO_TARGET" "$SS_VER"
# cd ../../../firmware/mcu/simpleserial-aes
# make PLATFORM=$1 CRYPTO_TARGET=$2 SS_VER=$3 -j

# %%
cw.program_target(scope, prog, "../../../firmware/mcu/simpleserial-aes/simpleserial-aes-{}.hex".format(PLATFORM))

# %% [markdown]
# The thing we want to test here is how hamming weight affects the power trace. To get as big a swing as possible, we'll convert all of the first bytes we send to be either `0x00` (HW of 0) or `0xFF` (HW of 8). 100 traces should be enough to see a difference:

# %%
from tqdm.notebook import trange
import numpy as np
import time

ktp = cw.ktp.Basic()
trace_array = []
textin_array = []

key, text = ktp.next()

target.set_key(key)

N = 100
for i in trange(N, desc='Capturing traces'):
    scope.arm()
    if text[0] & 0x01:
        text[0] = 0xFF
    else:
        text[0] = 0x00
    target.simpleserial_write('p', text)
    
    ret = scope.capture()
    if ret:
        print("Target timed out!")
        continue
    
    response = target.simpleserial_read('r', 16)
    
    trace_array.append(scope.get_last_trace())
    textin_array.append(text)
    
    key, text = ktp.next()
